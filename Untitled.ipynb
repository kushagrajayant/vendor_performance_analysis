# %%
import duckdb
import os
import logging
import time

os.makedirs("logs", exist_ok=True)

logging.basicConfig(
    filename="logs/app.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a",
    force=True
)

con = duckdb.connect("inventory.duckdb")

def load_raw_data():
    start = time.time()
    
    for file in os.listdir("data"):
        if file.endswith(".csv"):
            table_name = file[:-4] 
            
            con.execute(f""" 
                CREATE OR REPLACE TABLE {table_name} AS
                SELECT * FROM read_csv_auto('data/{file}')
            """)

    end =time.time()
    total_time = (end - start) / 60
    
    logging.info("Execution Complete")
    logging.info(f"Total Time Taken: {total_time} minutes")

load_raw_data()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
pip install duckdb
# Out:
# Collecting duckdb
#   Downloading duckdb-1.5.1-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Downloading duckdb-1.5.1-cp313-cp313-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/13.1 MB 7.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/13.1 MB 10.2 MB/s eta 0:00:01
#    ------------------ --------------------- 6.0/13.1 MB 10.9 MB/s eta 0:00:01
#    -------------------------- ------------- 8.7/13.1 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 10.0/13.1 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 10.7 MB/s  0:00:01
# Installing collected packages: duckdb
# Successfully installed duckdb-1.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
con = duckdb.connect('inventory.duckdb')

# %%
def load_raw_data():
    start = time.time()
    for file in os.listdir('data'):
        if file.endswith('.csv'):
            table_name = file[:-4] 

        
        con.execute(f""" 
            create or replace table {table_name} as
            select * from read_csv_auto('data/{file}')""")

    end =time.time()
    total_time = (end - start)/60
    logging.info('------------Execution Complete------------')

    logging.info(f'nTotal Time Taken: {total_time} minutes')

if __name__== '__main__':
    load_raw_data()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.execute('show tables').fetchall()
# Out:
# [('begin_inventory',),
#  ('end_inventory',),
#  ('purchase_prices',),
#  ('purchases',),
#  ('sales',),
#  ('vendor_invoice',)]

# %%
con.execute('select count(*) From sales').fetchall()
# Out:
# [(12825363,)]

# %%
import logging
import os

os.makedirs("logs", exist_ok=True)

logging.basicConfig(
    filename="logs/app.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    force=True
)

logging.info("test message")
print("logging check done")
# Out:
# logging check done
