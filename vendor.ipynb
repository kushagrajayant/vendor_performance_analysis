# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///inventory.db')

# %%
os.listdir('desktop/data')
# Out:
# ['.ipynb_checkpoints',
#  'begin_inventory.csv',
#  'data',
#  'end_inventory.csv',
#  'purchases.csv',
#  'purchase_prices.csv',
#  'sales.csv',
#  'Untitled.ipynb',
#  'vendor_invoice.csv',
#  '__MACOSX']
